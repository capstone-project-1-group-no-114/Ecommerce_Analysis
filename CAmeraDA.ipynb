# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Load the dataset
file_path = "/content/amazon_cameras_webscraping.csv"  # Replace with the actual path to your file
data = pd.read_csv(file_path, encoding='latin1')

# Display basic information about the dataset
print(data.info())

# Display the first few rows of the dataset
print(data.head())

# Summary statistics
print(data.describe(include='all'))

# Check for missing values
missing_values = data.isnull().sum()
print(missing_values)

# Convert RATING to float
data['RATING'] = data['RATING'].str.extract(r'(\d+\.\d+)').astype(float)

# Convert NUMBER OF RATING to int after removing commas
data['NUMBER OF RATING'] = data['NUMBER OF RATING'].str.replace(',', '').astype(int)

# Convert DISCOUNTED PRICE and M.R.P. to int after removing currency symbols
data['DISCOUNTED PRICE'] = data['DISCOUNTED PRICE'].str.replace(r'[\?,]', '', regex=True).astype(int, errors='ignore')
data['M.R.P.'] = pd.to_numeric(data['M.R.P.'].str.replace(r'[\?,]', '', regex=True), errors='coerce')

# Convert DISCOUNT to percentage
data['DISCOUNT'] = data['DISCOUNT'].str.extract(r'(\d+)%').astype(float)

# Extract brand names
data['BRAND'] = data['NAME OF CAMERA'].apply(lambda x: x.split()[0])

# Calculate total number of ratings for each brand
brand_ratings = data.groupby('BRAND')['NUMBER OF RATING'].sum().reset_index()

# Calculate market share for each brand
total_ratings = brand_ratings['NUMBER OF RATING'].sum()
brand_ratings['MARKET SHARE'] = (brand_ratings['NUMBER OF RATING'] / total_ratings) * 100

# Display the brand ratings and market share
print(brand_ratings)

# Get top 5 best-selling cameras for each brand
top_5_cameras = data.groupby('BRAND').apply(lambda x: x.nlargest(5, 'NUMBER OF RATING')).reset_index(drop=True)

# Display the top 5 best-selling cameras for each brand
print(top_5_cameras)

# Define price ranges
bins = [0, 20000, 40000, 60000, 80000, 100000, float('inf')]
labels = ['0-20K', '20K-40K', '40K-60K', '60K-80K', '80K-100K', '100K+']
data['PRICE RANGE'] = pd.cut(data['M.R.P.'], bins=bins, labels=labels)

# Identify top rated cameras within each price range
top_rated_per_price_range = data.groupby('PRICE RANGE').apply(lambda x: x.nlargest(1, 'RATING')).reset_index(drop=True)

# Display the top rated cameras per price range
print(top_rated_per_price_range)

# Plotting the distribution of ratings
plt.figure(figsize=(10, 6))
sns.histplot(data['RATING'], bins=20, kde=True)
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# Relationship between M.R.P. and discounted price
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data['M.R.P.'], y=data['DISCOUNTED PRICE'])
plt.title('M.R.P. vs Discounted Price')
plt.xlabel('M.R.P.')
plt.ylabel('Discounted Price')
plt.show()

# Distribution of discounts
plt.figure(figsize=(10, 6))
sns.histplot(data['DISCOUNT'], bins=20, kde=True)
plt.title('Distribution of Discounts')
plt.xlabel('Discount (%)')
plt.ylabel('Frequency')
plt.show()

# Top rated cameras
top_rated = data.nlargest(10, 'RATING')

fig = px.bar(top_rated, x='NAME OF CAMERA', y='RATING', title='Top 10 Rated Cameras')
fig.show()

# Plotting the market share of top-selling brands
fig = px.pie(brand_ratings, names='BRAND', values='MARKET SHARE', title='Market Share of Top-Selling Brands')
fig.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   NAME OF CAMERA    208 non-null    object
#  1   DISCOUNTED PRICE  208 non-null    object
#  2   M.R.P.            208 non-null    object
#  3   DISCOUNT          208 non-null    object
#  4   RATING            208 non-null    object
#  5   NUMBER OF RATING  208 non-null    object
#  6   URL OF CAMERA     208 non-null    object
# dtypes: object(7)
# memory usage: 11.5+ KB
# None
#                                       NAME OF CAMERA DISCOUNTED PRICE  \
# 0  Fujifilm X-T30 II 26.1MP APS-C X-Trans Sensor|...          ?93,000
# 1  Fujifilm X-T30 II 26.1MP APS-C X-Trans Sensor|...        ?1,16,000
# 2  Sony Alpha ZV-E10L 24.2 Mega Pixel Interchange...          ?61,489
# 3  Sony Alpha ILCE-6100Y 24.2 MP Mirrorless Digit...          ?73,990
# 4  Canon EOS R100 24.1 MP Mirrorless Camera (Blac...          ?47,999
#
#       M.R.P.   DISCOUNT              RATING NUMBER OF RATING  \
# 0    ?99,999   (7% off)  4.7 out of 5 stars               27
# 1  ?1,49,999  (23% off)  4.6 out of 5 stars               54
# 2    ?69,990  (12% off)  4.4 out of 5 stars              372
# 3    ?89,990  (18% off)  4.5 out of 5 stars              177
# 4    ?64,995  (26% off)  4.3 out of 5 stars               41
#
#                                        URL OF CAMERA
# 0  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2  https://www.amazon.in/Sony-ZV-E10L-Interchange...
# 3  https://www.amazon.in/Sony-ILCE-6100Y-Mirrorle...
# 4  https://www.amazon.in/Canon-Digital-Camera-R10...
#                                            NAME OF CAMERA DISCOUNTED PRICE  \
# count                                                 208              208
# unique                                                192              180
# top     Fujifilm X-T30 II 26.1MP APS-C X-Trans Sensor|...        ?1,34,990
# freq                                                    2                4
#
#            M.R.P.  DISCOUNT              RATING NUMBER OF RATING  \
# count         208       208                 208              208
# unique        177        40                  23               99
# top     ?2,19,999  (7% off)  5.0 out of 5 stars                1
# freq            4        21                  34               17
#
#                                             URL OF CAMERA
# count                                                 208
# unique                                                207
# top     https://www.amazon.in/Canon-Camcorder-Dual-Pix...
# freq                                                    2
# NAME OF CAMERA      0
# DISCOUNTED PRICE    0
# M.R.P.              0
# DISCOUNT            0
# RATING              0
# NUMBER OF RATING    0
# URL OF CAMERA       0
# dtype: int64
#             BRAND  NUMBER OF RATING  MARKET SHARE
# 0   (Refurbished)                37      0.101752
# 1              4K                 8      0.022000
# 2         ATPLOES                 4      0.011000
# 3          Acuvar                16      0.044001
# 4         BOFIDAR                 1      0.002750
# 5           Canon             14146     38.902181
# 6         Digital               214      0.588510
# 7        Fujifilm              4938     13.579738
# 8           KODAK               636      1.749031
# 9           Kodak              3717     10.221929
# 10      LEQTRONIQ                95      0.261255
# 11          Leica                 6      0.016500
# 12       Linsewsy                27      0.074251
# 13          Nikon              2462      6.770618
# 14             OM               111      0.305255
# 15        Olympus               757      2.081786
# 16      PANASONIC               850      2.337541
# 17      Panasonic              3236      8.899156
# 18          Razer              1948      5.357094
# 19          Ricoh               456      1.254022
# 20         Saneen               539      1.482276
# 21          Sigma                48      0.132002
# 22           Sony              2085      5.733850
# 23        Sorandy                 2      0.005500
# 24        UIKICON                 7      0.019250
# 25       VJIANGER                 1      0.002750
# 26             YI                16      0.044001
#                                        NAME OF CAMERA  DISCOUNTED PRICE  \
# 0   (Refurbished) Panasonic LUMIX G7 16.00 MP 4K M...             34999
# 1   (Refurbished) Nikon Mirrorless Z fc Body with ...             60999
# 2   (Refurbished) Nikon Z 6II Mirrorless Digital C...            135000
# 3   (Refurbished) Nikon Z50 Mirroless Camera Body ...             66000
# 4   4K Digital Camera for Photography 56MP 18X Dig...             16218
# ..                                                ...               ...
# 66  Sony Alpha ILCE-6100Y 24.2 MP Mirrorless Digit...             73990
# 67  Sorandy 4K Vlogging Camera For Youtube, 3 Inch...              9449
# 68  UIKICON 2024 Upgrade 4K 56MP Digital Camera fo...             14881
# 69  VJIANGER 2024 Upgrade 4K Digital Camera for Ph...             27228
# 70  YI 95013 20 MP Mirrorless Digital Camera (Blac...             59999
#
#     M.R.P.  DISCOUNT  RATING  NUMBER OF RATING  \
# 0    42500      18.0     4.1                18
# 1    86999      30.0     5.0                11
# 2   180599      25.0     4.7                 6
# 3    96200      31.0     4.3                 2
# 4    22218      27.0     4.2                 7
# ..     ...       ...     ...               ...
# 66   89990      18.0     4.5               177
# 67   17999      48.0     4.0                 2
# 68   20881      29.0     2.5                 7
# 69   35228      23.0     1.0                 1
# 70   89999      33.0     3.3                16
#
#                                         URL OF CAMERA          BRAND
# 0   https://www.amazon.in/Renewed-Panasonic-Mirror...  (Refurbished)
# 1   https://www.amazon.in/Renewed-Nikon-Mirrorless...  (Refurbished)
# 2   https://www.amazon.in/Renewed-Nikon-Mirrorless...  (Refurbished)
# 3   https://www.amazon.in/Renewed-Nikon-Mirroless-...  (Refurbished)
# 4   https://www.amazon.in/Photography-Vlogging-Bat...             4K
# ..                                                ...            ...
# 66  https://www.amazon.in/Sony-ILCE-6100Y-Mirrorle...           Sony
# 67  https://www.amazon.in/Sorandy-Vlogging-Youtube...        Sorandy
# 68  https://www.amazon.in/UIKICON-Photography-Vlog...        UIKICON
# 69  https://www.amazon.in/VJIANGER-Upgrade-Photogr...       VJIANGER
# 70  https://www.amazon.in/YI-Mirrorless-Digital-In...             YI
#
# [71 rows x 8 columns]
#                                       NAME OF CAMERA  DISCOUNTED PRICE  \
# 0  BOFIDAR Digital Camera 1080P FHD Kids Digital ...             12999
# 1  Razer 6o - USB Camera with High-Performance Ad...              8915
# 2  Panasonic LUMIX DMC-G7KK DSLM Mirrorless 4K Ca...             41490
# 3                     Panasonic Camera+ Tripod Stand             44039
# 4  Olympus OM-D E-M10 Mark III Mirrorless Micro F...             76038
# 5  Fujifilm X-T5 40MP APS-C X-Trans Sensor|Pixel ...            203999
#
#    M.R.P.  DISCOUNT  RATING  NUMBER OF RATING  \
# 0   17999      28.0     5.0                 1
# 1   24999      64.0     4.3              1948
# 2   54990      25.0     4.6               773
# 3   60989      27.0     4.7                 3
# 4   89990      16.0     5.0                 5
# 5  219999       7.0     5.0                12
#
#                                        URL OF CAMERA      BRAND PRICE RANGE
# 0  https://www.amazon.in/BOFIDAR-Digital-Batterie...    BOFIDAR       0-20K
# 1  https://www.amazon.in/6o-Camera-High-Performan...      Razer     20K-40K
# 2  https://www.amazon.in/PANASONIC-Mirrorless-14-...  Panasonic     40K-60K
# 3  https://www.amazon.in/Panasonic-Camera-Tripod-...  Panasonic     60K-80K
# 4  https://www.amazon.in/Olympus-Mirrorless-Third...    Olympus    80K-100K
# 5  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...   Fujifilm       100K+
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="da69de8f-c753-4875-9092-d06e36d2cd26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da69de8f-c753-4875-9092-d06e36d2cd26")) {                    Plotly.newPlot(                        "da69de8f-c753-4875-9092-d06e36d2cd26",                        [{"alignmentgroup":"True","hovertemplate":"NAME OF CAMERA=%{x}\u003cbr\u003eRATING=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Fujifilm X-T5 40MP APS-C X-Trans Sensor|Pixel Shift|IBIS System|Ultra high Resolution mirrorless Camera|6k 30p|1\u002f180000 Shutter Speed|Quick Lever for Photo\u002fVideo with XF 16-80mm f\u002f1:4 Lens -Black","Fujifilm X-T5 40MP APS-C X-Trans Sensor|Pixel Shift|IBIS System|Ultra high Resolution mirrorless Camera|6k 30p|1\u002f180000 Shutter Speed|Quick Lever for Photo\u002fVideo with XF 16-80mm f\u002f1:4 Lens -Silver","Fujifilm X-T5 40MP APS-C X-Trans Sensor|Pixel Shift|IBIS System|Ultra high Resolution mirrorless Camera|6k 30p|1\u002f180000 Shutter Speed|Quick Lever for Photo\u002fVideo with XF 16-80mm f\u002f1:4 Lens -Black","Fujifilm X-T5 40MP APS-C X-Trans Sensor|Pixel Shift|IBIS System|Ultra high Resolution mirrorless Camera|6k 30p|1\u002f180000 Shutter Speed|Quick Lever for Photo\u002fVideo with XF 18-55mm f\u002f2.8 Lens -Black","Sony Alpha ILCE-9M3 Full-Frame Interchangeable-Lens Mirrorless Camera (Body Only) | Global Shutter System | 24.6 MP | 120fps with AF\u002fAE Tracking | 4K 120p without cropping - Black","Fujifilm X-T5 40MP APS-C X-trans sensor|Pixel Shift|IBIS System|Ultra high resolution mirrorless camera|6.2k 30p|Subject tracking|1\u002f180000 shutter speed|Touchtracking|quick lever for photo\u002fvideo-Black","Fujifilm X-T5 40MP APS-C X-Trans Sensor|Pixel Shift|IBIS System|Ultra high Resolution mirrorless Camera|6k 30p|1\u002f180000 Shutter Speed|Quick Lever for Photo\u002fVideo with XF 16-80mm f\u002f1:4 Lens -Silver","Fujifilm X-T5 40MP APS-C X-trans sensor|Pixel Shift|IBIS System|Ultra high resolution mirrorless camera|6.2k 30p|Subject tracking|1\u002f180000 shutter speed|Touchtracking|quick lever for photo\u002fvideo-Black","Canon EOS R6 Mark II 24. 2 MP Mirrorless Camera with RF24-105mm f4 L is USM Lens Kit (Black)","Panasonic LUMIX GH5 II 4K Mirrorless Camera with Lecia Vario-Elmarit 12-60mm F2.8-4.0 Lens (DC-GH5M2LGW) Black"],"xaxis":"x","y":[5.0,5.0,5.0,5.0,5.0,5.0,5.0,5.0,5.0,5.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[ ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="23a95c1e-f18c-47b9-9776-3fa0173b7645" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23a95c1e-f18c-47b9-9776-3fa0173b7645")) {                    Plotly.newPlot(                        "23a95c1e-f18c-47b9-9776-3fa0173b7645",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"BRAND=%{label}\u003cbr\u003eMARKET SHARE=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["(Refurbished)","4K","ATPLOES","Acuvar","BOFIDAR","Canon","Digital","Fujifilm","KODAK","Kodak","LEQTRONIQ","Leica","Linsewsy","Nikon","OM","Olympus","PANASONIC","Panasonic","Razer","Ricoh","Saneen","Sigma","Sony","Sorandy","UIKICON","VJIANGER","YI"],"legendgroup":"","name":"","showlegend":true,"values":[0.10175178065616149,0.022000385006737618,0.011000192503368809,0.044000770013475236,0.0027500481258422023,38.90218078816379,0.5885102989302312,13.579737645408796,1.7490306080356406,10.221928883755465,0.26125457195500923,0.016500288755053213,0.07425129939773946,6.770618485823501,0.3052553419684845,2.081786431262547,2.337540906965872,8.899155735225367,5.35709374914061,1.2540219453840442,1.4822759398289471,0.1320023100404257,5.7338503423809914,0.0055000962516844045,0.019250336880895415,0.0027500481258422023,0.044000770013475236],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1. ...
